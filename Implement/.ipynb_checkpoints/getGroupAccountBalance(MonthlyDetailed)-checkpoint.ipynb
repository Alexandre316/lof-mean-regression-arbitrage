# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from dataclasses import dataclass
import empyrical

# %%
import os 
os.chdir("../")

# %%
matplotlib.rcParams['font.sans-serif'] = ['Times New Roman']

# %% [markdown]
# #### 1.数据导入

# %%
# 净值、价格和成交量数据
lof_open = pd.read_csv("./Data/LOF开盘价.CSV",index_col = 0)
lof_close = pd.read_csv("./Data/LOF收盘价.CSV",index_col = 0)
lof_high = pd.read_csv("./Data/LOF最高价.CSV",index_col = 0)
lof_low = pd.read_csv("./Data/LOF最低价.CSV",index_col = 0)
lof_avg = pd.read_csv("./Data/LOF平均价.CSV",index_col = 0)
lof_nav = pd.read_csv("./Data/LOF复权净值.CSV",index_col = 0)
lof_volume = pd.read_csv("./Data/LOF成交量.CSV",index_col = 0)

# 将SZ,SH结尾的场内LOF转换成OF结尾的
lof_open.columns = lof_open.columns.map(lambda x:x[:6]+".OF")
lof_close.columns = lof_close.columns.map(lambda x:x[:6]+".OF")
lof_high.columns = lof_high.columns.map(lambda x:x[:6]+".OF")
lof_low.columns = lof_low.columns.map(lambda x:x[:6]+".OF")
lof_avg.columns = lof_avg.columns.map(lambda x:x[:6]+".OF")
lof_nav.columns = lof_nav.columns.map(lambda x:x[:6]+".OF")
lof_volume.columns = lof_volume.columns.map(lambda x:x[:6]+".OF")

lof_open.index = pd.to_datetime(lof_open.index)
lof_close.index = pd.to_datetime(lof_close.index)
lof_high.index = pd.to_datetime(lof_high.index)
lof_low.index = pd.to_datetime(lof_low.index)
lof_avg.index = pd.to_datetime(lof_avg.index)
lof_nav.index = pd.to_datetime(lof_nav.index)
lof_volume.index = pd.to_datetime(lof_volume.index)

# %%
filled_lof_close = lof_close.asfreq("D").ffill()

# %%
trade_date = pd.read_excel("./Data/TradeDate.xlsx") 
month_begin_end = pd.read_excel("./Data/MonthBeginEnd.xlsx")

trade_month_begin = month_begin_end.MONTH_START_TRADE.tolist()
trade_month_end = month_begin_end.MONTH_END_TRADE.tolist()

# %%
# 导入到期日数据
maturity_period = pd.read_excel("./Output/MaturePeriod.xlsx",index_col = 0)

# %% [markdown]
# #### 2.计算年化折价率

# %%
discount_ratio = pd.read_csv("./Data/LOF溢价率.CSV",index_col = 0)
discount_ratio.index = pd.to_datetime(discount_ratio.index)
discount_ratio.columns = discount_ratio.columns.map(lambda x:x[:6]+".OF")

# %% [markdown]
# #### 3.构建买卖信号

# %%
start_date = pd.to_datetime("2013-12-31")
end_date = pd.to_datetime("2022-03-25")

# %%
@dataclass
class FundObject:
    vt_symbol:str = ""
    buy_price:float = 0.0
    volume:float = 0.0
    
    def __post_init__(self):
        self.price:float = self.buy_price
        self.last_price:float = self.price
        self.pnl:float = (self.price - self.buy_price)*self.volume
        self.daily_pnl:float = (self.price - self.last_price)*self.volume
        self.status:str = "HOLDING"
        self.discount_pct:float = 0.0

# %%
# 记录仓位变化
'''account'''
capital:float = 300000.0 # 本金
available:float = capital
in_position_lof:dict = {}
backtest_result:pd.DataFrame = pd.DataFrame(columns = [f"Group {i}" for i in range(14)])
'''variables'''

'''paramaters'''
upper_year:int = 365 # 距离下次开放最远的购买时间
lower_year:int = 90 # 距离下次开放最近的购买时间

single_position_limit:float = 0.1 # 个基最大的仓位限制
single_buy_limit:float = 0.01 # 每次购买2%成的仓位

profit_stop_upper:float = 0.15 # 个基止盈
profit_stop_lower:float = 0.05  # 个基止损

adding_percent:float = 0.98 # 当购买价格小于或等于该值倍数时才能加仓平摊成本
discount_ubs:list = [-8,-6,-4,-2,-1,-0.5,0,0.5,1,2,4,6,8,10] # 14 sections
discount_lbs:list = [-10,-8,-6,-4,-2,-1,-0.5,0,0.5,1,2,4,6,8]
    
buy_cost:float = 0.005
sell_cost:float = 0.005

# %%
for ix, (discount_lb,discount_ub) in enumerate(zip(discount_lbs,discount_ubs)):
    
    # init account data
    capital:float = 300000.0
    available:float = capital
    in_pool_lof:list = list()
    in_position_lof:dict = {}
        
    # group backtesting
    print(f"processing group {ix}|{discount_lb} {discount_ub}")
    for date in trade_date.loc[(trade_date.DATE>=start_date)&(trade_date.DATE<=end_date)].DATE:
        """"""
        if date in trade_month_end:
            # buy condition: discount ratio in [0,0.06]
            daily_discount_lof = discount_ratio.loc[date,(discount_ratio.loc[date,:]<=discount_ub)&\
                                                   (discount_ratio.loc[date,:]>=discount_lb)].dropna()
            in_pool_lof = daily_discount_lof.index.tolist() # have lof at the end of months

            # adjust and clear
            for to_sell_lof in in_position_lof.keys():
                price = filled_lof_close.at[date,to_sell_lof]
                in_position_lof[to_sell_lof].last_price = in_position_lof[to_sell_lof].price
                in_position_lof[to_sell_lof].price = price
                in_position_lof[to_sell_lof].pnl = (in_position_lof[to_sell_lof].price - \
                                                    in_position_lof[to_sell_lof].buy_price)*in_position_lof[to_sell_lof].volume
                in_position_lof[to_sell_lof].daily_pnl = (in_position_lof[to_sell_lof].price - \
                                                          in_position_lof[to_sell_lof].last_price)*in_position_lof[to_sell_lof].volume
                in_position_lof[to_sell_lof].discount_pct = discount_ratio.at[date,to_sell_lof]

                # sell
                if to_sell_lof not in in_pool_lof:
                    sell_price = filled_lof_close.at[date,to_sell_lof]
                    print(f"sell {to_sell_lof} at {sell_price}")
                    in_position_lof[to_sell_lof].status = "SOLD"

        elif date in trade_month_begin: # buy at the beginning of months
            # buy
            for to_buy_lof in in_pool_lof:
                if to_buy_lof not in in_position_lof.keys():
                    for after in range(1,10): # ten days to ask price 
                        try:
                            trade_volume = lof_volume.loc[date:,to_buy_lof].iloc[after] # deal if there is volume
                        except IndexError: # no deal after 5 trade days
                            break # cancel ask
                        if pd.isnull(trade_volume) or trade_volume == 0: # no trade volume in the day
                            continue # ask on the next day
                        else:
                            buy_price = lof_high.loc[date:,to_buy_lof].iloc[after]
                            buy_date = lof_high.loc[date:,[to_buy_lof]].iloc[after].name
                            buy_volume = min(capital/len(in_pool_lof)/(buy_price*(1+buy_cost)),trade_volume)
                            if buy_price*buy_volume*(1+buy_cost)<=available: # enough money
                                in_position_lof[to_buy_lof] = FundObject(
                                    vt_symbol = to_buy_lof,
                                    buy_price = buy_price, # today's pnl is moved to the next day
                                    volume = buy_volume,
                                )
                                print(f"buy {to_buy_lof}|buy date:{buy_date}|buy price:{buy_price}|buy volume:{buy_volume}")
                                available -= in_position_lof[to_buy_lof].volume*in_position_lof[to_buy_lof].price*(1+buy_cost)
                                capital -= in_position_lof[to_buy_lof].volume*in_position_lof[to_buy_lof].price*buy_cost
                                break # dealed

                            elif available >= 1000: # not enough money
                                buy_volume = min((available-1)/(buy_price*(1+buy_cost)),trade_volume)
                                in_position_lof[to_buy_lof] = FundObject(
                                    vt_symbol = to_buy_lof,
                                    buy_price = buy_price,
                                    volume = buy_volume,
                                )
                                print(f"scaled buy {to_buy_lof}|buy price:{buy_price}|buy volume:{buy_volume}")
                                available -= in_position_lof[to_buy_lof].volume*in_position_lof[to_buy_lof].price*(1+buy_cost)
                                capital -= in_position_lof[to_buy_lof].volume*in_position_lof[to_buy_lof].price*buy_cost
                                break # dealed

                # else in position, adjust position, adjust buy price and volume
                else:
                    # update and buy
                    price = filled_lof_close.at[date,to_buy_lof]
                    in_position_lof[to_buy_lof].last_price = in_position_lof[to_buy_lof].price
                    in_position_lof[to_buy_lof].price = price
                    in_position_lof[to_buy_lof].pnl = (in_position_lof[to_buy_lof].price - \
                                                       in_position_lof[to_buy_lof].buy_price)*in_position_lof[to_buy_lof].volume
                    in_position_lof[to_buy_lof].daily_pnl = (in_position_lof[to_buy_lof].price - \
                                                             in_position_lof[to_buy_lof].last_price)*in_position_lof[to_buy_lof].volume

                    buy_price = filled_lof_close.at[date,to_buy_lof]
                    buy_volume = capital/len(in_pool_lof)/(buy_price*(1+buy_cost))
                    to_buy_volume = buy_volume - in_position_lof[to_buy_lof].volume

                    if to_buy_volume<=0: # sell those over weight
                        print(f"sell adjust {to_buy_lof}|buy date:{date}|buy price:{buy_price}|volume from {in_position_lof[to_buy_lof].volume} to {buy_volume}")
                        available -= buy_price*to_buy_volume*(1-sell_cost)
                        capital += buy_price*to_buy_volume*sell_cost # negative + negative = positive
                        in_position_lof[to_buy_lof].volume += to_buy_volume

                    elif buy_price*to_buy_volume*(1+buy_cost)<=available: # add those lower than the weight
                        for after in range(1,10): # 5 days to ask price 
                            try:
                                trade_volume = lof_volume.loc[date:,to_buy_lof].iloc[after] # deal if there is volume
                            except IndexError: # no deal after 5 trade days
                                break # cancel ask
                            if pd.isnull(trade_volume) or trade_volume == 0: # no trade volume in the day
                                continue # ask on the next day
                            else:
                                buy_price = lof_high.loc[date:,to_buy_lof].iloc[after]
                                buy_date = lof_high.loc[date:,[to_buy_lof]].iloc[after].name
                                buy_volume = min(to_buy_volume,trade_volume)
                                break

                        # if ten days no trade, next lof
                        if pd.isnull(trade_volume) or trade_volume == 0:
                            continue
                        print(f"buy adjust {to_buy_lof}|buy date:{date}|buy price:{buy_price}|volume from {in_position_lof[to_buy_lof].volume} to {buy_volume}")
                        adjusted_buy_price = (buy_price*buy_volume+in_position_lof[to_buy_lof].price*\
                                              in_position_lof[to_buy_lof].volume)/(in_position_lof[to_buy_lof].volume+buy_volume)
                        in_position_lof[to_buy_lof].buy_price = adjusted_buy_price
                        in_position_lof[to_buy_lof].volume += buy_volume
                        available -= buy_price*buy_volume*(1+buy_cost)
                        capital -= buy_volume*(buy_price - filled_lof_close.at[date,to_buy_lof])
                        capital -= buy_volume*buy_price*buy_cost

                    elif buy_price*to_buy_volume*(1+buy_cost)>available: # not enough money
                        print(f"Not Enough Money in Account:{available}")

        else:
            for to_adjust_lof in in_position_lof.keys():
                price = filled_lof_close.at[date,to_adjust_lof]
                in_position_lof[to_adjust_lof].last_price = in_position_lof[to_adjust_lof].price
                in_position_lof[to_adjust_lof].price = price
                in_position_lof[to_adjust_lof].pnl = (in_position_lof[to_adjust_lof].price - \
                                                      in_position_lof[to_adjust_lof].buy_price)*in_position_lof[to_adjust_lof].volume
                in_position_lof[to_adjust_lof].daily_pnl = (in_position_lof[to_adjust_lof].price - \
                                                            in_position_lof[to_adjust_lof].last_price)*in_position_lof[to_adjust_lof].volume

        # daily profit and loss
        for to_settle_lof in list(in_position_lof.keys()):
            capital += in_position_lof[to_settle_lof].daily_pnl
            # close->open, sell
            if maturity_period.at[to_settle_lof,date] == 0: 
                print(f"sell {to_settle_lof}|sell date:{date}|sell price:{in_position_lof[to_settle_lof].price}")
                in_position_lof[to_settle_lof].status = "SOLD"

            # profit and loss stop
            # profit stop
            if in_position_lof[to_settle_lof].price/in_position_lof[to_settle_lof].buy_price-1 >= profit_stop_upper:
                print(f"profit {to_settle_lof}|sell date:{date}|sell price:{in_position_lof[to_settle_lof].price}")
                in_position_lof[to_settle_lof].status = "SOLD"
            # loss stop
            elif in_position_lof[to_settle_lof].price/in_position_lof[to_settle_lof].buy_price-1 <= -profit_stop_lower:
                print(f"loss {to_settle_lof}|sell date:{date}|sell price:{in_position_lof[to_settle_lof].price}")
                in_position_lof[to_settle_lof].status = "SOLD"

            # cancel sold records
            if in_position_lof[to_settle_lof].status == "SOLD":
                available += in_position_lof[to_settle_lof].price*in_position_lof[to_settle_lof].volume*(1-sell_cost) # release money
                capital -= in_position_lof[to_settle_lof].price*in_position_lof[to_settle_lof].volume*sell_cost # sell cost
                del in_position_lof[to_settle_lof]
        backtest_result.loc[date,f"Group {ix}"] = capital
# Out:
# processing group 0|-10 -8
# buy 166902.OF|buy date:2014-03-04 00:00:00|buy price:0.9918|buy volume:200.0
# sell 166902.OF at 0.9803
# buy 160621.OF|buy date:2014-04-02 00:00:00|buy price:0.921|buy volume:20700.0
# buy 161911.OF|buy date:2014-04-02 00:00:00|buy price:0.9399|buy volume:52700.0
# buy 163210.OF|buy date:2014-04-02 00:00:00|buy price:0.932|buy volume:106638.745026655
# buy adjust 160621.OF|buy date:2014-05-05 00:00:00|buy price:0.948|volume from 20700.0 to 58469.27522827666
# buy adjust 161911.OF|buy date:2014-05-05 00:00:00|buy price:0.9553|volume from 52700.0 to 26075.922339728713
# sell adjust 163210.OF|buy date:2014-05-05 00:00:00|buy price:0.938|volume from 106638.745026655 to 79450.43002114851
# buy 164105.OF|buy date:2014-05-06 00:00:00|buy price:1.0939|buy volume:68098.34871468831
# loss 164105.OF|sell date:2014-05-16 00:00:00|sell price:0.9932
# sell 160621.OF at 0.99
# sell 161911.OF at 0.99
# sell 163210.OF at 0.981
# buy 165513.OF|buy date:2014-06-04 00:00:00|buy price:0.806|buy volume:5792.0
# loss 165513.OF|sell date:2014-06-04 00:00:00|sell price:0.7
# scaled buy 161222.OF|buy price:1.2|buy volume:249347.9827016677
# loss 161222.OF|sell date:2015-06-18 00:00:00|sell price:1.14
# buy 160216.OF|buy date:2015-09-02 00:00:00|buy price:0.533|buy volume:264004.94411479344
# buy 161222.OF|buy date:2015-09-02 00:00:00|buy price:0.846|buy volume:165915.60142692903
# sell 160216.OF|sell date:2015-09-08 00:00:00|sell price:0.527
# sell 161222.OF at 0.854
# buy 161222.OF|buy date:2015-11-03 00:00:00|buy price:0.925|buy volume:300949.52600165753
# sell 161222.OF at 0.987
# buy 169102.OF|buy date:2016-02-02 00:00:00|buy price:1.1823|buy volume:138100.0
# sell 169102.OF at 1.165
# buy 160642.OF|buy date:2016-12-02 00:00:00|buy price:0.941|buy volume:39000.0
# buy 162411.OF|buy date:2016-12-02 00:00:00|buy price:0.709|buy volume:204449.23520817477
# sell 162411.OF|sell date:2016-12-27 00:00:00|sell price:0.727
# buy adjust 160642.OF|buy date:2017-01-03 00:00:00|buy price:0.941|volume from 39000.0 to 37100.0
# buy 161834.OF|buy date:2017-01-04 00:00:00|buy price:0.91|buy volume:79826.83992886398
# buy 168103.OF|buy date:2017-01-04 00:00:00|buy price:0.91|buy volume:79727.5528145246
# buy 501022.OF|buy date:2017-01-04 00:00:00|buy price:0.93|buy volume:77915.9507143818
# buy adjust 160642.OF|buy date:2017-02-03 00:00:00|buy price:0.935|volume from 76100.0 to 2576.7394538254157
# sell adjust 161834.OF|buy date:2017-02-03 00:00:00|buy price:0.913|volume from 79826.83992886398 to 79787.39905064576
# buy adjust 168103.OF|buy date:2017-02-03 00:00:00|buy price:0.908|volume from 79727.5528145246 to 676.255734346385
# sell adjust 501022.OF|buy date:2017-02-03 00:00:00|buy price:0.937|volume from 77915.9507143818 to 77742.5297417691
# sell 168103.OF at 0.887
# sell 501022.OF at 0.931
# buy 160421.OF|buy date:2017-03-02 00:00:00|buy price:0.862|buy volume:47557.360206534926
# sell adjust 160642.OF|buy date:2017-03-01 00:00:00|buy price:0.933|volume from 78676.73945382542 to 43907.08299281006
# buy 161232.OF|buy date:2017-03-02 00:00:00|buy price:0.898|buy volume:45592.70848648613
# sell adjust 161834.OF|buy date:2017-03-01 00:00:00|buy price:0.905|volume from 79787.39905064576 to 45207.904143478
# buy 162717.OF|buy date:2017-03-02 00:00:00|buy price:0.92|buy volume:44446.6427023613
# buy 168101.OF|buy date:2017-03-02 00:00:00|buy price:1.2888|buy volume:31705.345130977195
# buy 168105.OF|buy date:2017-03-02 00:00:00|buy price:0.924|buy volume:44191.34954444966
# sell 160642.OF at 0.923
# sell 161834.OF at 0.895
# sell 161232.OF at 0.888
# sell 168101.OF at 1.2596
# sell 168105.OF at 0.902
# buy adjust 160421.OF|buy date:2017-04-05 00:00:00|buy price:0.87|volume from 47557.360206534926 to 17601.40845066435
# buy 160921.OF|buy date:2017-04-06 00:00:00|buy price:0.93|buy volume:60643.274780193264
# buy adjust 162717.OF|buy date:2017-04-05 00:00:00|buy price:0.931|volume from 44446.6427023613 to 16136.290510886502
# buy 169201.OF|buy date:2017-04-06 00:00:00|buy price:0.924|buy volume:60956.675909623154
# buy 501028.OF|buy date:2017-04-06 00:00:00|buy price:0.937|buy volume:60051.147055176356
# sell 501028.OF at 0.922
# sell adjust 160421.OF|buy date:2017-05-02 00:00:00|buy price:0.835|volume from 65158.768657199274 to 47273.3284720031
# buy 160642.OF|buy date:2017-05-04 00:00:00|buy price:0.905|buy volume:1000.0
# sell adjust 160921.OF|buy date:2017-05-02 00:00:00|buy price:0.925|volume from 60643.274780193264 to 42661.59107638321
# sell adjust 162717.OF|buy date:2017-05-02 00:00:00|buy price:0.922|volume from 60582.9332132478 to 42787.5814518281
# buy 167001.OF|buy date:2017-05-03 00:00:00|buy price:0.858|buy volume:45965.604771998966
# buy 168301.OF|buy date:2017-05-03 00:00:00|buy price:0.908|buy volume:43403.58887241843
# sell adjust 169201.OF|buy date:2017-05-02 00:00:00|buy price:0.91|volume from 60956.675909623154 to 43277.415846040785
# loss 160421.OF|sell date:2017-05-11 00:00:00|sell price:0.821
# loss 167001.OF|sell date:2017-05-12 00:00:00|sell price:0.812
# loss 169201.OF|sell date:2017-05-23 00:00:00|sell price:0.864
# sell 162717.OF at 0.892
# sell 160642.OF at 0.905
# sell 168301.OF at 0.877
# buy 160518.OF|buy date:2017-06-02 00:00:00|buy price:0.85|buy volume:44823.3474495666
# buy 160519.OF|buy date:2017-06-02 00:00:00|buy price:0.835|buy volume:45596.12760574973
# buy adjust 160921.OF|buy date:2017-06-01 00:00:00|buy price:0.91|volume from 42661.59107638321 to 572.166895467155
# buy 161233.OF|buy date:2017-06-02 00:00:00|buy price:0.916|buy volume:4600.0
# buy 169201.OF|buy date:2017-06-02 00:00:00|buy price:0.85|buy volume:4300.0
# buy 501015.OF|buy date:2017-06-02 00:00:00|buy price:0.872|buy volume:43620.762094816346
# buy 501032.OF|buy date:2017-06-05 00:00:00|buy price:0.856|buy volume:44404.52127931094
# sell 160921.OF at 0.901
# sell 160518.OF at 0.904
# sell 161233.OF at 0.936
# sell 169201.OF at 0.847
# sell 501015.OF at 0.926
# sell 501032.OF at 0.868
# buy adjust 160519.OF|buy date:2017-07-03 00:00:00|buy price:0.899|volume from 45596.12760574973 to 15362.360012436002
# buy 162717.OF|buy date:2017-07-04 00:00:00|buy price:0.912|buy volume:1000.0
# buy 165528.OF|buy date:2017-07-04 00:00:00|buy price:0.922|buy volume:59074.78577680763
# buy 167003.OF|buy date:2017-07-04 00:00:00|buy price:0.939|buy volume:3800.0
# buy 501026.OF|buy date:2017-07-04 00:00:00|buy price:0.865|buy volume:62900.816261077845
# sell 160519.OF at 0.903
# sell 162717.OF at 0.942
# sell 165528.OF at 0.965
# buy 161233.OF|buy date:2017-08-02 00:00:00|buy price:0.929|buy volume:29679.30661433045
# buy 167001.OF|buy date:2017-08-02 00:00:00|buy price:0.802|buy volume:34362.042885341616
# buy 167002.OF|buy date:2017-08-02 00:00:00|buy price:0.893|buy volume:30845.070288888346
# buy adjust 167003.OF|buy date:2017-08-01 00:00:00|buy price:0.923|volume from 3800.0 to 2500.0
# buy 169201.OF|buy date:2017-08-02 00:00:00|buy price:0.875|buy volume:31462.62394647698
# buy 501022.OF|buy date:2017-08-02 00:00:00|buy price:0.919|buy volume:29941.34878919506
# sell adjust 501026.OF|buy date:2017-08-01 00:00:00|buy price:0.879|volume from 62900.816261077845 to 31288.293441991384
# buy 501027.OF|buy date:2017-08-02 00:00:00|buy price:0.95|buy volume:13493.0
# buy 501028.OF|buy date:2017-08-02 00:00:00|buy price:0.917|buy volume:29969.692547523
# buy 501032.OF|buy date:2017-08-02 00:00:00|buy price:0.907|buy volume:30285.04446058127
# sell 167003.OF at 0.939
# sell 501026.OF at 0.884
# sell 167001.OF at 0.813
# sell 167002.OF at 0.928
# sell 501022.OF at 0.897
# sell 501027.OF at 0.962
# sell 501028.OF at 0.9
# buy 160519.OF|buy date:2017-09-04 00:00:00|buy price:0.923|buy volume:33146.55599029735
# buy 160642.OF|buy date:2017-09-04 00:00:00|buy price:0.92|buy volume:33236.25969891627
# buy 160921.OF|buy date:2017-09-04 00:00:00|buy price:0.884|buy volume:13200.0
# buy 161232.OF|buy date:2017-09-04 00:00:00|buy price:0.83|buy volume:36812.05494135039
# buy adjust 161233.OF|buy date:2017-09-01 00:00:00|buy price:0.94|volume from 29679.30661433045 to 2600.0
# buy 168301.OF|buy date:2017-09-04 00:00:00|buy price:0.927|buy volume:32938.86442603479
# buy 168401.OF|buy date:2017-09-04 00:00:00|buy price:0.9|buy volume:33908.275781503056
# buy adjust 169201.OF|buy date:2017-09-01 00:00:00|buy price:0.888|volume from 31462.62394647698 to 3315.686674283268
# buy adjust 501032.OF|buy date:2017-09-01 00:00:00|buy price:0.955|volume from 30285.04446058127 to 2399.755613842124
# sell 161233.OF at 0.959
# sell 169201.OF at 0.912
# sell 160519.OF at 0.971
# sell 161232.OF at 0.845
# sell 168301.OF at 0.94
# buy 160324.OF|buy date:2017-10-10 00:00:00|buy price:0.923|buy volume:43500.62962924048
# buy adjust 160642.OF|buy date:2017-10-09 00:00:00|buy price:0.94|volume from 33236.25969891627 to 9906.261255292164
# buy adjust 160921.OF|buy date:2017-10-09 00:00:00|buy price:0.924|volume from 13200.0 to 30771.32109323427
# buy adjust 168401.OF|buy date:2017-10-09 00:00:00|buy price:0.93|volume from 33908.275781503056 to 500.0
# buy 501022.OF|buy date:2017-10-10 00:00:00|buy price:0.933|buy volume:42902.19916676517
# buy 501028.OF|buy date:2017-10-10 00:00:00|buy price:0.961|buy volume:41622.58357577669
# buy adjust 501032.OF|buy date:2017-10-09 00:00:00|buy price:0.983|volume from 32684.800074423394 to 3900.0
# sell 501032.OF at 0.986
# sell 160921.OF at 0.956
# sell 501022.OF at 0.913
# sell 501028.OF at 0.955
# buy adjust 160324.OF|buy date:2017-11-01 00:00:00|buy price:0.914|volume from 43500.62962924048 to 17880.04213529348
# buy adjust 160642.OF|buy date:2017-11-01 00:00:00|buy price:0.96|volume from 43142.520954208434 to 15585.932385622567
# buy 161233.OF|buy date:2017-11-02 00:00:00|buy price:0.97|buy volume:9300.0
# buy 168104.OF|buy date:2017-11-02 00:00:00|buy price:1.0|buy volume:400.0
# buy adjust 168401.OF|buy date:2017-11-01 00:00:00|buy price:0.937|volume from 34408.275781503056 to 26051.16582036943
# loss 160324.OF|sell date:2017-11-27 00:00:00|sell price:0.862
# sell 160642.OF at 0.94
# sell 161233.OF at 0.931
# sell 168104.OF at 0.977
# buy 160324.OF|buy date:2017-12-04 00:00:00|buy price:0.845|buy volume:54301.21510400185
# buy 160921.OF|buy date:2017-12-05 00:00:00|buy price:0.901|buy volume:50883.99544018004
# buy 168301.OF|buy date:2017-12-04 00:00:00|buy price:0.892|buy volume:51354.78090617603
# sell adjust 168401.OF|buy date:2017-12-01 00:00:00|buy price:0.928|volume from 60459.44160187249 to 49321.63875737367
# buy 501022.OF|buy date:2017-12-04 00:00:00|buy price:0.85|buy volume:53837.5416288876
# buy 501032.OF|buy date:2017-12-04 00:00:00|buy price:0.98|buy volume:10989.0
# loss 501032.OF|sell date:2017-12-04 00:00:00|sell price:0.911
# sell 160324.OF at 0.853
# sell 160921.OF at 0.922
# sell 168301.OF at 0.898
# buy 160642.OF|buy date:2018-01-03 00:00:00|buy price:0.95|buy volume:5102.0
# buy 168104.OF|buy date:2018-01-03 00:00:00|buy price:0.964|buy volume:70796.29141201387
# buy adjust 168401.OF|buy date:2018-01-02 00:00:00|buy price:0.931|volume from 49321.63875737367 to 24050.524660880386
# buy adjust 501022.OF|buy date:2018-01-02 00:00:00|buy price:0.856|volume from 53837.5416288876 to 28238.271419402605
# sell 168401.OF at 0.953
# sell 501022.OF at 0.844
# sell 160642.OF at 0.978
# sell 168104.OF at 0.9887
# buy 501032.OF|buy date:2018-02-05 00:00:00|buy price:0.898|buy volume:69202.0
# loss 501032.OF|sell date:2018-02-09 00:00:00|sell price:0.85
# buy 160921.OF|buy date:2018-03-02 00:00:00|buy price:0.9078|buy volume:8400.0
# buy 168401.OF|buy date:2018-03-02 00:00:00|buy price:0.998|buy volume:71827.0
# buy 501022.OF|buy date:2018-03-02 00:00:00|buy price:0.796|buy volume:113739.19679342257
# loss 168401.OF|sell date:2018-03-23 00:00:00|sell price:0.94
# sell 160921.OF at 0.9446
# sell 501022.OF at 0.79
# buy 166023.OF|buy date:2018-04-03 00:00:00|buy price:0.909|buy volume:50700.0
# buy 166024.OF|buy date:2018-04-03 00:00:00|buy price:0.901|buy volume:98257.62910975057
# buy 501046.OF|buy date:2018-04-04 00:00:00|buy price:0.903|buy volume:97877.417167369
# loss 166023.OF|sell date:2018-04-09 00:00:00|sell price:0.862
# buy 166023.OF|buy date:2018-05-03 00:00:00|buy price:0.888|buy volume:1100.0
# sell adjust 166024.OF|buy date:2018-05-02 00:00:00|buy price:0.91|volume from 98257.62910975057 to 94944.38954091884
# buy adjust 501046.OF|buy date:2018-05-02 00:00:00|buy price:0.879|volume from 97877.417167369 to 1312.4730767429428
# sell 166024.OF at 0.999
# sell 166023.OF at 0.918
# buy 501028.OF|buy date:2018-06-04 00:00:00|buy price:0.801|buy volume:168159.91567724553
# buy adjust 501046.OF|buy date:2018-06-01 00:00:00|buy price:0.888|volume from 99189.89024411194 to 52117.573214067175
# loss 501046.OF|sell date:2018-06-19 00:00:00|sell price:0.826
# loss 501028.OF|sell date:2018-06-19 00:00:00|sell price:0.73
# buy 501046.OF|buy date:2018-07-03 00:00:00|buy price:0.83|buy volume:213289.0
# sell 501046.OF at 0.842
# buy 163417.OF|buy date:2018-08-02 00:00:00|buy price:0.836|buy volume:295354.239494647
# sell 163417.OF at 0.83
# buy 169106.OF|buy date:2018-09-04 00:00:00|buy price:0.929|buy volume:130626.89710042585
# buy 501028.OF|buy date:2018-09-04 00:00:00|buy price:0.75|buy volume:161400.68772777627
# loss 501028.OF|sell date:2018-09-11 00:00:00|sell price:0.701
# sell 169106.OF at 0.934
# buy 501028.OF|buy date:2018-10-09 00:00:00|buy price:0.712|buy volume:148200.0
# loss 501028.OF|sell date:2018-10-17 00:00:00|sell price:0.666
# buy 161834.OF|buy date:2018-11-02 00:00:00|buy price:0.708|buy volume:79558.68606738198
# buy 169106.OF|buy date:2018-11-02 00:00:00|buy price:0.931|buy volume:60426.950154934595
# buy 501053.OF|buy date:2018-11-02 00:00:00|buy price:0.93|buy volume:5700.0
# buy 501307.OF|buy date:2018-11-02 00:00:00|buy price:0.933|buy volume:200.0
# sell 169106.OF at 0.937
# sell 501053.OF at 0.942
# sell 501307.OF at 0.887
# buy adjust 161834.OF|buy date:2018-12-03 00:00:00|buy price:0.72|volume from 79558.68606738198 to 77065.48615050576
# buy 501054.OF|buy date:2018-12-04 00:00:00|buy price:0.771|buy volume:145579.0477824679
# sell adjust 161834.OF|buy date:2019-01-02 00:00:00|buy price:0.704|volume from 156624.17221788774 to 155643.06367537103
# Not Enough Money in Account:1749.772503510595
# sell 161834.OF at 0.724
# sell 501054.OF at 0.792
# buy 501032.OF|buy date:2019-02-11 00:00:00|buy price:0.696|buy volume:2100.0
# buy 501062.OF|buy date:2019-02-11 00:00:00|buy price:0.905|buy volume:125662.69620322098
# sell 501032.OF at 0.7228
# sell 501062.OF at 0.908
# buy 161132.OF|buy date:2019-03-04 00:00:00|buy price:0.95|buy volume:119336.61894527185
# buy 166023.OF|buy date:2019-03-04 00:00:00|buy price:0.957|buy volume:118169.04242424584
# sell adjust 161132.OF|buy date:2019-04-01 00:00:00|buy price:1.012|volume from 119336.61894527185 to 58072.5051344064
# sell adjust 166023.OF|buy date:2019-04-01 00:00:00|buy price:1.021|volume from 118169.04242424584 to 57485.07508298725
# buy 169102.OF|buy date:2019-04-02 00:00:00|buy price:1.9761|buy volume:29662.061160575013
# buy 501049.OF|buy date:2019-04-02 00:00:00|buy price:0.942|buy volume:62146.80953606182
# sell 161132.OF at 1.052
# sell 166023.OF at 1.052
# sell 169102.OF at 1.9078
# sell 501049.OF at 0.957
# buy 160726.OF|buy date:2019-05-07 00:00:00|buy price:1.021|buy volume:118077.666886981
# buy 501054.OF|buy date:2019-05-07 00:00:00|buy price:0.895|buy volume:134365.81465447802
# sell 501054.OF at 0.865
# sell adjust 160726.OF|buy date:2019-06-03 00:00:00|buy price:0.979|volume from 118077.666886981 to 117667.39675210585
# buy 501064.OF|buy date:2019-06-05 00:00:00|buy price:1.05|buy volume:10800.0
# loss 501064.OF|sell date:2019-06-04 00:00:00|sell price:0.973
# loss 160726.OF|sell date:2019-06-05 00:00:00|sell price:0.96
# buy 160642.OF|buy date:2019-07-03 00:00:00|buy price:0.9086|buy volume:49893.914171124576
# buy 161132.OF|buy date:2019-07-02 00:00:00|buy price:1.1|buy volume:41171.36576892566
# buy 166025.OF|buy date:2019-07-02 00:00:00|buy price:0.945|buy volume:47876.65519513702
# buy 501054.OF|buy date:2019-07-02 00:00:00|buy price:0.92|buy volume:49128.71827389368
# buy 501065.OF|buy date:2019-07-02 00:00:00|buy price:1.145|buy volume:39435.325116974185
# loss 160642.OF|sell date:2019-07-02 00:00:00|sell price:0.834
# sell 161132.OF at 1.123
# sell 166025.OF at 0.997
# sell 501065.OF at 1.174
# buy 161912.OF|buy date:2019-08-02 00:00:00|buy price:0.885|buy volume:42502.272198618935
# buy 168101.OF|buy date:2019-08-02 00:00:00|buy price:1.1991|buy volume:31342.941720809813
# buy 169102.OF|buy date:2019-08-02 00:00:00|buy price:1.7956|buy volume:20913.431611155433
# sell adjust 501054.OF|buy date:2019-08-01 00:00:00|buy price:0.919|volume from 49128.71827389368 to 40828.09578349978
# buy 501063.OF|buy date:2019-08-02 00:00:00|buy price:0.94|buy volume:39909.24974253301
# buy 501070.OF|buy date:2019-08-02 00:00:00|buy price:1.009|buy volume:37149.24484232877
# sell 168101.OF|sell date:2019-08-13 00:00:00|sell price:1.1783
# sell 161912.OF at 0.952
# sell 169102.OF at 1.8132
# buy 166024.OF|buy date:2019-09-03 00:00:00|buy price:0.875|buy volume:52145.67916531814
# buy 168101.OF|buy date:2019-09-03 00:00:00|buy price:1.2407|buy volume:36738.993151219795
# buy adjust 501054.OF|buy date:2019-09-02 00:00:00|buy price:0.921|volume from 40828.09578349978 to 8668.331945171281
# buy adjust 501063.OF|buy date:2019-09-02 00:00:00|buy price:0.952|volume from 39909.24974253301 to 7863.095120579266
# buy adjust 501070.OF|buy date:2019-09-02 00:00:00|buy price:1.085|volume from 37149.24484232877 to 5039.041557265526
# sell 501054.OF at 0.951
# sell 501070.OF at 1.165
# sell 166024.OF at 0.875
# sell 168101.OF at 1.2578
# buy 169102.OF|buy date:2019-10-09 00:00:00|buy price:1.864|buy volume:17964.463554479335
# buy 169103.OF|buy date:2019-10-09 00:00:00|buy price:1.5183|buy volume:22039.09679412357
# buy 501062.OF|buy date:2019-10-09 00:00:00|buy price:1.0166|buy volume:32892.16818265272
# sell adjust 501063.OF|buy date:2019-10-08 00:00:00|buy price:0.97|volume from 47772.344863112274 to 34447.84803033842
# buy 501071.OF|buy date:2019-10-09 00:00:00|buy price:1.051|buy volume:31784.23077719854
# buy 501075.OF|buy date:2019-10-09 00:00:00|buy price:0.943|buy volume:35399.241125723405
# buy 501081.OF|buy date:2019-10-09 00:00:00|buy price:0.949|buy volume:35150.431075444234
# sell 501063.OF at 1.005
# sell 501062.OF at 1.0543
# sell 501071.OF at 1.097
# sell 501075.OF at 0.925
# buy adjust 169102.OF|buy date:2019-11-01 00:00:00|buy price:2.0199|volume from 17964.463554479335 to 22402.480912219733
# buy adjust 169103.OF|buy date:2019-11-01 00:00:00|buy price:1.6191|volume from 22039.09679412357 to 27539.61311712692
# buy adjust 501081.OF|buy date:2019-11-01 00:00:00|buy price:0.977|volume from 35150.431075444234 to 46608.40173747583
# sell 169102.OF at 2.0584
# sell 169103.OF at 1.6318
# sell 501081.OF at 0.975
# buy 501077.OF|buy date:2019-12-03 00:00:00|buy price:0.983|buy volume:123219.71126341166
# buy 501078.OF|buy date:2019-12-03 00:00:00|buy price:0.978|buy volume:123541.58513400635
# sell 501078.OF at 1.008
# buy 168105.OF|buy date:2020-01-03 00:00:00|buy price:1.062|buy volume:61275.556943422445
# sell adjust 501077.OF|buy date:2020-01-02 00:00:00|buy price:1.152|volume from 123219.71126341166 to 56418.14484819118
# buy 501080.OF|buy date:2020-01-03 00:00:00|buy price:1.069|buy volume:60709.06191568249
# buy 501081.OF|buy date:2020-01-03 00:00:00|buy price:1.022|buy volume:63421.98463632821
# profit 501077.OF|sell date:2020-01-02 00:00:00|sell price:1.152
# buy adjust 168105.OF|buy date:2020-02-03 00:00:00|buy price:1.078|volume from 61275.556943422445 to 6813.83384673328
# scaled buy 501077.OF|buy price:1.232|buy volume:50318.66366938648
# Not Enough Money in Account:1.0
# Not Enough Money in Account:1.0
# loss 501080.OF|sell date:2020-02-03 00:00:00|sell price:1.006
# profit 501081.OF|sell date:2020-02-17 00:00:00|sell price:1.186
# profit 168105.OF|sell date:2020-02-18 00:00:00|sell price:1.203
# sell 501077.OF at 1.202
# buy 168105.OF|buy date:2020-03-03 00:00:00|buy price:1.189|buy volume:116027.90467864013
# buy 501081.OF|buy date:2020-03-03 00:00:00|buy price:1.188|buy volume:115836.70168480862
# loss 501081.OF|sell date:2020-03-09 00:00:00|sell price:1.098
# loss 168105.OF|sell date:2020-03-12 00:00:00|sell price:1.118
# buy 168102.OF|buy date:2020-04-02 00:00:00|buy price:1.0835|buy volume:117533.35277828379
# buy 501064.OF|buy date:2020-04-02 00:00:00|buy price:1.4|buy volume:6881.0
# sell 168102.OF at 1.1448
# sell 501064.OF at 1.535
# buy 160645.OF|buy date:2020-05-07 00:00:00|buy price:1.098|buy volume:194701.0
# sell adjust 160645.OF|buy date:2020-06-01 00:00:00|buy price:1.234|volume from 194701.0 to 32379.511778710443
# buy 161729.OF|buy date:2020-06-02 00:00:00|buy price:1.208|buy volume:3600.0
# buy 161837.OF|buy date:2020-06-02 00:00:00|buy price:1.057|buy volume:37664.0148730463
# buy 169102.OF|buy date:2020-06-02 00:00:00|buy price:2.1583|buy volume:18432.362907781822
# buy 501062.OF|buy date:2020-06-02 00:00:00|buy price:1.2326|buy volume:32252.38854209223
# buy 501066.OF|buy date:2020-06-02 00:00:00|buy price:1.366|buy volume:29082.020106785632
# buy 501088.OF|buy date:2020-06-02 00:00:00|buy price:0.996|buy volume:39857.233831567966
# profit 160645.OF|sell date:2020-06-05 00:00:00|sell price:1.279
# sell 161729.OF at 1.36
# sell 161837.OF at 1.196
# sell 501062.OF at 1.3566
# buy adjust 169102.OF|buy date:2020-07-01 00:00:00|buy price:2.3948|volume from 18432.362907781822 to 7236.026681549425
# buy 169103.OF|buy date:2020-07-02 00:00:00|buy price:1.9584|buy volume:30796.646925908706
# buy adjust 501066.OF|buy date:2020-07-01 00:00:00|buy price:1.486|volume from 29082.020106785632 to 12471.180753093184
# buy 501083.OF|buy date:2020-07-02 00:00:00|buy price:1.44|buy volume:41766.91354134676
# buy adjust 501088.OF|buy date:2020-07-01 00:00:00|buy price:1.0979|volume from 39857.233831567966 to 15884.959664757334
# profit 501083.OF|sell date:2020-07-09 00:00:00|sell price:1.66
# sell 501066.OF at 1.57
# buy 160526.OF|buy date:2020-08-04 00:00:00|buy price:1.2547|buy volume:24193.286704048536
# buy 167508.OF|buy date:2020-08-04 00:00:00|buy price:1.097|buy volume:27658.694259261832
# buy 168105.OF|buy date:2020-08-04 00:00:00|buy price:1.442|buy volume:21031.806232149873
# sell adjust 169102.OF|buy date:2020-08-03 00:00:00|buy price:2.6278|volume from 25668.389589331247 to 11535.941767946906
# sell adjust 169103.OF|buy date:2020-08-03 00:00:00|buy price:2.0911|volume from 30796.646925908706 to 14488.714645014745
# buy 501077.OF|buy date:2020-08-04 00:00:00|buy price:1.868|buy volume:16210.882024848079
# buy 501078.OF|buy date:2020-08-04 00:00:00|buy price:1.85|buy volume:16361.20626487705
# buy 501079.OF|buy date:2020-08-04 00:00:00|buy price:1.826|buy volume:16568.752328655886
# sell adjust 501088.OF|buy date:2020-08-03 00:00:00|buy price:1.2407|volume from 55742.1934963253 to 24374.029262451746
# buy 501091.OF|buy date:2020-08-04 00:00:00|buy price:1.199|buy volume:25207.0524588494
# buy 501096.OF|buy date:2020-08-04 00:00:00|buy price:1.143|buy volume:26430.08434125189
# profit 501088.OF|sell date:2020-08-05 00:00:00|sell price:1.2477
# loss 501077.OF|sell date:2020-08-07 00:00:00|sell price:1.774
# loss 501078.OF|sell date:2020-08-07 00:00:00|sell price:1.757
# loss 501079.OF|sell date:2020-08-07 00:00:00|sell price:1.707
# loss 501096.OF|sell date:2020-08-11 00:00:00|sell price:1.085
# loss 168105.OF|sell date:2020-08-12 00:00:00|sell price:1.361
# profit 169102.OF|sell date:2020-08-28 00:00:00|sell price:2.7644
# sell 169103.OF at 2.211
# sell 167508.OF at 1.138
# buy adjust 160526.OF|buy date:2020-09-01 00:00:00|buy price:1.2826|volume from 24193.286704048536 to 6500.0
# buy 160527.OF|buy date:2020-09-02 00:00:00|buy price:0.957|buy volume:49187.79951277291
# buy 168105.OF|buy date:2020-09-02 00:00:00|buy price:1.42|buy volume:33126.245098459156
# buy 501062.OF|buy date:2020-09-02 00:00:00|buy price:1.4867|buy volume:31617.566236778555
# buy 501077.OF|buy date:2020-09-02 00:00:00|buy price:1.85|buy volume:25390.501172996585
# buy 501088.OF|buy date:2020-09-02 00:00:00|buy price:1.2667|buy volume:37056.16354337966
# buy adjust 501091.OF|buy date:2020-09-01 00:00:00|buy price:1.227|volume from 25207.0524588494 to 13654.323911000378
# loss 501088.OF|sell date:2020-09-08 00:00:00|sell price:1.1948
# loss 501091.OF|sell date:2020-09-09 00:00:00|sell price:1.127
# loss 501077.OF|sell date:2020-09-09 00:00:00|sell price:1.717
# sell 168105.OF|sell date:2020-09-21 00:00:00|sell price:1.412
# loss 501062.OF|sell date:2020-09-28 00:00:00|sell price:1.4118
# sell 160526.OF at 1.2372
# sell 160527.OF at 0.946
# buy 168103.OF|buy date:2020-10-12 00:00:00|buy price:1.369|buy volume:38161.78693442083
# buy 169107.OF|buy date:2020-10-12 00:00:00|buy price:1.114|buy volume:46858.31837776456
# buy 501066.OF|buy date:2020-10-12 00:00:00|buy price:1.705|buy volume:30590.547186238804
# buy 501088.OF|buy date:2020-10-12 00:00:00|buy price:1.2447|buy volume:41868.4302422752
# buy 501091.OF|buy date:2020-10-12 00:00:00|buy price:1.236|buy volume:42128.17407211832
# buy 501098.OF|buy date:2020-10-12 00:00:00|buy price:1.08|buy volume:48173.376865312006
# sell 501066.OF at 1.82
# sell 501088.OF at 1.2587
# sell 501091.OF at 1.24
# sell 501098.OF at 1.05
# buy 160527.OF|buy date:2020-11-03 00:00:00|buy price:0.963|buy volume:81208.21143950129
# buy adjust 168103.OF|buy date:2020-11-02 00:00:00|buy price:1.401|volume from 38161.78693442083 to 18232.60986842461
# buy adjust 169107.OF|buy date:2020-11-02 00:00:00|buy price:1.111|volume from 46858.31837776456 to 24376.294377904458
# buy 501078.OF|buy date:2020-11-03 00:00:00|buy price:1.738|buy volume:44805.06141099218
# profit 169107.OF|sell date:2020-11-23 00:00:00|sell price:1.3
# sell 168103.OF at 1.485
# sell 160527.OF at 1.048
# buy adjust 501078.OF|buy date:2020-12-01 00:00:00|buy price:1.741|volume from 44805.06141099218 to 148976.2680499181
# sell 501078.OF at 1.867
# buy 501076.OF|buy date:2021-01-05 00:00:00|buy price:1.528|buy volume:58691.10386994259
# buy 501081.OF|buy date:2021-01-05 00:00:00|buy price:1.6096|buy volume:55646.41178949132
# buy 501083.OF|buy date:2021-01-05 00:00:00|buy price:1.835|buy volume:48750.44188210262
# buy 501098.OF|buy date:2021-01-05 00:00:00|buy price:1.186|buy volume:75333.72331584869
# loss 501083.OF|sell date:2021-01-11 00:00:00|sell price:1.741
# profit 501081.OF|sell date:2021-01-22 00:00:00|sell price:1.8538
# buy 160926.OF|buy date:2021-02-02 00:00:00|buy price:1.147|buy volume:31859.645492720625
# buy 166027.OF|buy date:2021-02-02 00:00:00|buy price:1.017|buy volume:35914.289849045075
# buy 501075.OF|buy date:2021-02-02 00:00:00|buy price:1.603|buy volume:22773.962082272974
# sell adjust 501076.OF|buy date:2021-02-01 00:00:00|buy price:1.522|volume from 58691.10386994259 to 23974.046451947917
# buy 501078.OF|buy date:2021-02-02 00:00:00|buy price:2.075|buy volume:17572.14961945403
# buy 501079.OF|buy date:2021-02-02 00:00:00|buy price:2.178|buy volume:16732.81453496465
# buy 501081.OF|buy date:2021-02-02 00:00:00|buy price:1.7788|buy volume:20477.81576288235
# scaled buy 501082.OF|buy price:1.915|buy volume:10566.813554294717
# sell adjust 501098.OF|buy date:2021-02-01 00:00:00|buy price:1.177|volume from 75333.72331584869 to 30924.170717434456
# buy 506002.OF|buy date:2021-02-02 00:00:00|buy price:0.985|buy volume:36925.628363147
# loss 501078.OF|sell date:2021-02-22 00:00:00|sell price:1.96
# loss 501076.OF|sell date:2021-02-24 00:00:00|sell price:1.43
# loss 160926.OF|sell date:2021-02-24 00:00:00|sell price:1.076
# loss 501079.OF|sell date:2021-02-24 00:00:00|sell price:2.069
# loss 501081.OF|sell date:2021-02-24 00:00:00|sell price:1.6506
# loss 501082.OF|sell date:2021-02-24 00:00:00|sell price:1.772
# sell 501098.OF at 1.109
# sell 166027.OF at 0.989
# sell 501075.OF at 1.514
# sell 506002.OF at 0.937
# loss 501098.OF|sell date:2021-02-26 00:00:00|sell price:1.109
# loss 501075.OF|sell date:2021-02-26 00:00:00|sell price:1.514
# buy 168207.OF|buy date:2021-03-02 00:00:00|buy price:0.96|buy volume:118454.4810040236
# buy 501081.OF|buy date:2021-03-02 00:00:00|buy price:1.6356|buy volume:69410.4411319993
# buy 501099.OF|buy date:2021-03-02 00:00:00|buy price:1.496|buy volume:49300.0
# loss 168207.OF|sell date:2021-03-05 00:00:00|sell price:0.907
# loss 501081.OF|sell date:2021-03-08 00:00:00|sell price:1.5095
# loss 501099.OF|sell date:2021-03-08 00:00:00|sell price:1.408
# buy 169107.OF|buy date:2021-04-02 00:00:00|buy price:1.268|buy volume:35937.07703325348
# buy 501046.OF|buy date:2021-04-02 00:00:00|buy price:2.164|buy volume:21042.4338669409
# buy 501088.OF|buy date:2021-04-02 00:00:00|buy price:1.5254|buy volume:29830.512073085523
# buy 501091.OF|buy date:2021-04-02 00:00:00|buy price:1.497|buy volume:30374.831226773007
# buy 501092.OF|buy date:2021-04-02 00:00:00|buy price:1.169|buy volume:38869.80715337509
# buy 501099.OF|buy date:2021-04-02 00:00:00|buy price:1.435|buy volume:31642.167071356726
# buy 506003.OF|buy date:2021-04-02 00:00:00|buy price:0.778|buy volume:58321.642526296215
# loss 501099.OF|sell date:2021-04-12 00:00:00|sell price:1.362
# sell 501046.OF at 2.249
# sell 501088.OF at 1.5214
# sell 506003.OF at 0.807
# buy 160527.OF|buy date:2021-05-07 00:00:00|buy price:1.0057|buy volume:28637.237988246758
# sell adjust 169107.OF|buy date:2021-05-06 00:00:00|buy price:1.257|volume from 35937.07703325348 to 22901.70584877136
# buy 501063.OF|buy date:2021-05-07 00:00:00|buy price:1.3191|buy volume:21817.931445104714
# buy 501076.OF|buy date:2021-05-07 00:00:00|buy price:1.45|buy volume:19839.321806645505
# buy 501079.OF|buy date:2021-05-07 00:00:00|buy price:2.062|buy volume:13944.716662125296
# buy 501080.OF|buy date:2021-05-07 00:00:00|buy price:1.605|buy volume:17907.165594750182
# buy 501081.OF|buy date:2021-05-07 00:00:00|buy price:1.6006|buy volume:17948.270450949345
# scaled buy 501085.OF|buy price:1.435|buy volume:17687.371733784894
# sell adjust 501091.OF|buy date:2021-05-06 00:00:00|buy price:1.481|volume from 30374.831226773007 to 19381.18087444334
# sell adjust 501092.OF|buy date:2021-05-06 00:00:00|buy price:1.143|volume from 38869.80715337509 to 25106.006097154826
# buy 501099.OF|buy date:2021-05-07 00:00:00|buy price:1.404|buy volume:20433.796029551093
# sell 169107.OF at 1.286
# sell 501091.OF at 1.58
# sell 160527.OF at 1.0057
# sell 501076.OF at 1.544
# sell 501079.OF at 2.314
# sell 501080.OF at 1.707
# sell 501081.OF at 1.6887
# sell 501085.OF at 1.439
# sell 501099.OF at 1.448
# buy 501049.OF|buy date:2021-06-02 00:00:00|buy price:1.7075|buy volume:27322.873032353364
# buy adjust 501063.OF|buy date:2021-06-01 00:00:00|buy price:1.3728|volume from 21817.931445104714 to 12142.33031741613
# buy 501078.OF|buy date:2021-06-02 00:00:00|buy price:2.056|buy volume:22669.649883917486
# buy 501082.OF|buy date:2021-06-02 00:00:00|buy price:1.906|buy volume:24436.34511703068
# buy 501083.OF|buy date:2021-06-02 00:00:00|buy price:1.859|buy volume:25036.348019773195
# buy adjust 501092.OF|buy date:2021-06-01 00:00:00|buy price:1.16|volume from 25106.006097154826 to 14988.383274995675
# buy 506003.OF|buy date:2021-06-02 00:00:00|buy price:0.984|buy volume:47253.18547901843
# loss 506003.OF|sell date:2021-06-08 00:00:00|sell price:0.924
# sell 501063.OF at 1.3409
# sell 501078.OF at 2.135
# sell 501082.OF at 2.053
# buy adjust 501049.OF|buy date:2021-07-01 00:00:00|buy price:1.6315|volume from 27322.873032353364 to 5741.1462539688255
# buy 501066.OF|buy date:2021-07-02 00:00:00|buy price:2.075|buy volume:25993.340112066984
# buy 501077.OF|buy date:2021-07-02 00:00:00|buy price:2.456|buy volume:21942.775867780227
# buy 501079.OF|buy date:2021-07-02 00:00:00|buy price:2.268|buy volume:23741.96270454687
# buy adjust 501083.OF|buy date:2021-07-01 00:00:00|buy price:1.856|volume from 25036.348019773195 to 4077.354550422504
# buy adjust 501092.OF|buy date:2021-07-01 00:00:00|buy price:1.146|volume from 40094.3893721505 to 6761.392849463598
# loss 501066.OF|sell date:2021-07-22 00:00:00|sell price:1.97
# loss 501049.OF|sell date:2021-07-26 00:00:00|sell price:1.5247
# loss 501077.OF|sell date:2021-07-27 00:00:00|sell price:2.329
# sell 501079.OF at 2.255
# buy 161040.OF|buy date:2021-08-03 00:00:00|buy price:1.355|buy volume:25219.83553108591
# buy 161912.OF|buy date:2021-08-03 00:00:00|buy price:2.8646|buy volume:11922.776885174597
# buy 166027.OF|buy date:2021-08-03 00:00:00|buy price:1.072|buy volume:31842.450213077565
# buy 501054.OF|buy date:2021-08-03 00:00:00|buy price:1.7276|buy volume:19747.763966365404
# buy 501075.OF|buy date:2021-08-03 00:00:00|buy price:2.083|buy volume:16369.360470054253
# buy 501078.OF|buy date:2021-08-03 00:00:00|buy price:2.409|buy volume:14146.33836245056
# sell adjust 501083.OF|buy date:2021-08-02 00:00:00|buy price:1.788|volume from 29113.7025701957 to 19049.04406632611
# sell adjust 501092.OF|buy date:2021-08-02 00:00:00|buy price:1.102|volume from 46855.7822216141 to 30898.133365625163
# loss 501083.OF|sell date:2021-08-12 00:00:00|sell price:1.753
# sell 161040.OF at 1.378
# sell 161912.OF at 3.0827
# sell 166027.OF at 1.076
# sell 501075.OF at 2.164
# sell 501078.OF at 2.48
# buy 160143.OF|buy date:2021-09-02 00:00:00|buy price:1.237|buy volume:13208.675626088772
# buy 160325.OF|buy date:2021-09-02 00:00:00|buy price:1.152|buy volume:14179.560216889644
# buy 160527.OF|buy date:2021-09-02 00:00:00|buy price:1.1337|buy volume:14404.671527326329
# buy 160926.OF|buy date:2021-09-02 00:00:00|buy price:1.219|buy volume:13393.191116650887
# buy 162720.OF|buy date:2021-09-02 00:00:00|buy price:1.103|buy volume:14797.846737594127
# buy 166025.OF|buy date:2021-09-02 00:00:00|buy price:1.8681|buy volume:8734.945158901206
# buy 168207.OF|buy date:2021-09-02 00:00:00|buy price:1.188|buy volume:13731.884065854692
# sell adjust 501054.OF|buy date:2021-09-01 00:00:00|buy price:1.7169|volume from 19747.763966365404 to 9499.217547876622
# buy 501079.OF|buy date:2021-09-02 00:00:00|buy price:2.284|buy volume:7138.616107683168
# buy 501080.OF|buy date:2021-09-02 00:00:00|buy price:1.704|buy volume:9565.921275022038
# buy 501082.OF|buy date:2021-09-02 00:00:00|buy price:2.099|buy volume:7763.726361718423
# buy 501083.OF|buy date:2021-09-02 00:00:00|buy price:1.74|buy volume:9363.100305450505
# buy 501085.OF|buy date:2021-09-02 00:00:00|buy price:1.985|buy volume:8205.304053932306
# buy 501091.OF|buy date:2021-09-02 00:00:00|buy price:1.445|buy volume:11268.69458800668
# sell adjust 501092.OF|buy date:2021-09-01 00:00:00|buy price:1.126|volume from 30898.133365625163 to 14457.371162551906
# buy 506001.OF|buy date:2021-09-02 00:00:00|buy price:1.2729|buy volume:12785.098993403522
# buy 506002.OF|buy date:2021-09-02 00:00:00|buy price:1.143|buy volume:14234.375453906358
# buy 506003.OF|buy date:2021-09-02 00:00:00|buy price:0.966|buy volume:16838.127220247665
# buy 506006.OF|buy date:2021-09-02 00:00:00|buy price:1.1762|buy volume:13825.345826597508
# loss 168207.OF|sell date:2021-09-03 00:00:00|sell price:1.128
# loss 506002.OF|sell date:2021-09-13 00:00:00|sell price:1.076
# loss 501054.OF|sell date:2021-09-16 00:00:00|sell price:1.639
# loss 162720.OF|sell date:2021-09-16 00:00:00|sell price:1.045
# loss 501082.OF|sell date:2021-09-16 00:00:00|sell price:1.972
# loss 506006.OF|sell date:2021-09-22 00:00:00|sell price:1.1145
# loss 501085.OF|sell date:2021-09-24 00:00:00|sell price:1.809
# loss 506001.OF|sell date:2021-09-28 00:00:00|sell price:1.205
# loss 506003.OF|sell date:2021-09-28 00:00:00|sell price:0.914
# loss 166025.OF|sell date:2021-09-29 00:00:00|sell price:1.7603
# sell 501092.OF at 1.132
# sell 160527.OF at 1.0913
# sell 160926.OF at 1.282
# sell 501079.OF at 2.365
# sell 501080.OF at 1.687
# sell 501083.OF at 1.776
# sell 501091.OF at 1.43
# buy adjust 160143.OF|buy date:2021-10-08 00:00:00|buy price:1.182|volume from 13208.675626088772 to 2569.6490622874717
# buy adjust 160325.OF|buy date:2021-10-08 00:00:00|buy price:1.132|volume from 14179.560216889644 to 2396.2264709692536
# buy 160529.OF|buy date:2021-10-11 00:00:00|buy price:1.157|buy volume:16144.61802424075
# buy 161914.OF|buy date:2021-10-11 00:00:00|buy price:1.033|buy volume:18076.97464358979
# buy 162720.OF|buy date:2021-10-11 00:00:00|buy price:1.072|buy volume:17413.907057515833
# buy 166027.OF|buy date:2021-10-11 00:00:00|buy price:1.056|buy volume:17672.257320048422
# buy 168207.OF|buy date:2021-10-11 00:00:00|buy price:1.143|buy volume:16322.04803080431
# buy 169107.OF|buy date:2021-10-11 00:00:00|buy price:1.192|buy volume:15646.224725512011
# buy 501049.OF|buy date:2021-10-11 00:00:00|buy price:1.4543|buy volume:12820.257615494087
# buy 501066.OF|buy date:2021-10-11 00:00:00|buy price:1.76|buy volume:10590.172290259456
# buy 501085.OF|buy date:2021-10-11 00:00:00|buy price:1.678|buy volume:11104.23576530416
# buy 501096.OF|buy date:2021-10-11 00:00:00|buy price:1.149|buy volume:16211.587292971044
# buy 506001.OF|buy date:2021-10-11 00:00:00|buy price:1.1918|buy volume:15624.535816937689
# buy 506002.OF|buy date:2021-10-11 00:00:00|buy price:1.075|buy volume:17316.773557793495
# buy 506003.OF|buy date:2021-10-11 00:00:00|buy price:0.933|buy volume:19946.13415119907
# buy 506006.OF|buy date:2021-10-11 00:00:00|buy price:1.1256|buy volume:16528.03531573265
# loss 501085.OF|sell date:2021-10-13 00:00:00|sell price:1.584
# loss 161914.OF|sell date:2021-10-27 00:00:00|sell price:0.978
# sell 166027.OF at 1.018
# sell 169107.OF at 1.188
# sell 501049.OF at 1.4135
# sell 501066.OF at 1.68
# sell 501096.OF at 1.172
# sell 506003.OF at 0.913
# sell 506006.OF at 1.0983
# buy adjust 160143.OF|buy date:2021-11-01 00:00:00|buy price:1.269|volume from 15778.324688376244 to 2276.131825100987
# buy adjust 160325.OF|buy date:2021-11-01 00:00:00|buy price:1.158|volume from 16575.786687858897 to 3270.9182251408747
# buy adjust 160529.OF|buy date:2021-11-01 00:00:00|buy price:1.191|volume from 16144.61802424075 to 3275.1490713346793
# buy 161914.OF|buy date:2021-11-02 00:00:00|buy price:1.003|buy volume:22685.654325233485
# buy adjust 162720.OF|buy date:2021-11-01 00:00:00|buy price:1.128|volume from 17413.907057515833 to 2948.674321383478
# buy adjust 168207.OF|buy date:2021-11-01 00:00:00|buy price:1.199|volume from 16322.04803080431 to 2901.322953749097
# buy 501082.OF|buy date:2021-11-02 00:00:00|buy price:2.079|buy volume:10936.201770771566
# buy 501085.OF|buy date:2021-11-02 00:00:00|buy price:1.695|buy volume:13408.650284657004
# buy 501098.OF|buy date:2021-11-02 00:00:00|buy price:1.28|buy volume:17749.190869951126
# buy 501099.OF|buy date:2021-11-02 00:00:00|buy price:1.695|buy volume:13398.38921728092
# buy 501200.OF|buy date:2021-11-02 00:00:00|buy price:1.214|buy volume:18699.817512751953
# buy adjust 506001.OF|buy date:2021-11-01 00:00:00|buy price:1.1827|volume from 15624.535816937689 to 3795.9952261373255
# buy adjust 506002.OF|buy date:2021-11-01 00:00:00|buy price:1.164|volume from 17316.773557793495 to 2479.951231730447
# sell 160143.OF at 1.28
# sell 168207.OF at 1.29
# sell 501082.OF at 2.184
# sell 501085.OF at 1.662
# sell 501098.OF at 1.313
# profit 506001.OF|sell date:2021-11-30 00:00:00|sell price:1.3489
# buy adjust 160325.OF|buy date:2021-12-01 00:00:00|buy price:1.253|volume from 19846.704912999772 to 875.2428639413592
# buy adjust 160529.OF|buy date:2021-12-01 00:00:00|buy price:1.261|volume from 19419.76709557543 to 1219.5819195072545
# buy adjust 161914.OF|buy date:2021-12-01 00:00:00|buy price:1.056|volume from 22685.654325233485 to 1990.6045132605796
# buy adjust 162720.OF|buy date:2021-12-01 00:00:00|buy price:1.205|volume from 20362.58137889931 to 1217.7623696377123
# buy 501054.OF|buy date:2021-12-02 00:00:00|buy price:1.6294|buy volume:15945.761950171529
# buy 501062.OF|buy date:2021-12-02 00:00:00|buy price:1.7551|buy volume:14797.591326976797
# buy adjust 501099.OF|buy date:2021-12-01 00:00:00|buy price:1.887|volume from 13398.38921728092 to 388.37924811525954
# buy adjust 501200.OF|buy date:2021-12-01 00:00:00|buy price:1.208|volume from 18699.817512751953 to 3042.2698915244073
# buy 506001.OF|buy date:2021-12-02 00:00:00|buy price:1.3388|buy volume:19386.76206047048
# buy adjust 506002.OF|buy date:2021-12-01 00:00:00|buy price:1.227|volume from 19796.72478952394 to 1330.5034420283373
# buy 506003.OF|buy date:2021-12-02 00:00:00|buy price:1.037|buy volume:25018.003622283977
# buy 506006.OF|buy date:2021-12-02 00:00:00|buy price:1.2306|buy volume:21073.389951503308
# loss 162720.OF|sell date:2021-12-20 00:00:00|sell price:1.131
# loss 506003.OF|sell date:2021-12-20 00:00:00|sell price:0.974
# loss 506002.OF|sell date:2021-12-24 00:00:00|sell price:1.162
# loss 506001.OF|sell date:2021-12-24 00:00:00|sell price:1.2688
# loss 160325.OF|sell date:2021-12-27 00:00:00|sell price:1.19
# sell 160529.OF at 1.259
# sell 161914.OF at 1.051
# sell 501099.OF at 1.845
# sell 501200.OF at 1.19
# sell 501054.OF at 1.6582
# sell 501062.OF at 1.8055
# sell 506006.OF at 1.2347
# buy 169107.OF|buy date:2022-01-05 00:00:00|buy price:1.242|buy volume:61029.24299888157
# buy 501095.OF|buy date:2022-01-05 00:00:00|buy price:0.987|buy volume:76701.1583459382
# buy 501096.OF|buy date:2022-01-05 00:00:00|buy price:1.134|buy volume:66675.38274217001
# buy 501098.OF|buy date:2022-01-05 00:00:00|buy price:1.292|buy volume:58448.7940288741
# loss 501096.OF|sell date:2022-01-10 00:00:00|sell price:1.077
# loss 501098.OF|sell date:2022-01-27 00:00:00|sell price:1.2
# sell 169107.OF at 1.191
# sell 501095.OF at 0.95
# buy 501202.OF|buy date:2022-02-08 00:00:00|buy price:1.119|buy volume:254874.31982745478
# loss 501202.OF|sell date:2022-02-11 00:00:00|sell price:1.058
# buy 169107.OF|buy date:2022-03-02 00:00:00|buy price:1.166|buy volume:28620.698525549775
# buy 501054.OF|buy date:2022-03-02 00:00:00|buy price:1.5048|buy volume:22163.065466887052
# buy 501062.OF|buy date:2022-03-02 00:00:00|buy price:1.6602|buy volume:20076.03918491681
# buy 501096.OF|buy date:2022-03-02 00:00:00|buy price:1.006|buy volume:33110.84740899245
# buy 501098.OF|buy date:2022-03-02 00:00:00|buy price:1.155|buy volume:14000.0
# buy 501202.OF|buy date:2022-03-02 00:00:00|buy price:1.06|buy volume:31395.039294663693
# buy 506000.OF|buy date:2022-03-02 00:00:00|buy price:0.9109|buy volume:36511.193234696555
# buy 506005.OF|buy date:2022-03-02 00:00:00|buy price:0.9637|buy volume:34489.3255713485
# loss 169107.OF|sell date:2022-03-07 00:00:00|sell price:1.087
# loss 501054.OF|sell date:2022-03-07 00:00:00|sell price:1.4137
# loss 501096.OF|sell date:2022-03-07 00:00:00|sell price:0.928
# loss 501202.OF|sell date:2022-03-07 00:00:00|sell price:1.001
# loss 501098.OF|sell date:2022-03-08 00:00:00|sell price:1.083
# loss 506000.OF|sell date:2022-03-08 00:00:00|sell price:0.8632
# loss 506005.OF|sell date:2022-03-08 00:00:00|sell price:0.9069
# loss 501062.OF|sell date:2022-03-15 00:00:00|sell price:1.5264
# processing group 1|-8 -6
# buy 160125.OF|buy date:2014-01-09 00:00:00|buy price:1.1207|buy volume:17600.0
# buy 160128.OF|buy date:2014-01-03 00:00:00|buy price:0.9844|buy volume:50523.04817508017
# buy 160515.OF|buy date:2014-01-03 00:00:00|buy price:0.997|buy volume:1600.0
# buy 160621.OF|buy date:2014-01-03 00:00:00|buy price:0.92|buy volume:54013.39821848767
# buy 161911.OF|buy date:2014-01-06 00:00:00|buy price:0.9196|buy volume:12300.0
# buy 163210.OF|buy date:2014-01-03 00:00:00|buy price:0.909|buy volume:5502.0
# sell 160125.OF|sell date:2014-01-02 00:00:00|sell price:1.1207
# loss 160515.OF|sell date:2014-01-07 00:00:00|sell price:0.945
# loss 160128.OF|sell date:2014-01-20 00:00:00|sell price:0.9306
# buy 160125.OF|buy date:2014-02-10 00:00:00|buy price:1.1891|buy volume:7900.0
# buy 160128.OF|buy date:2014-02-10 00:00:00|buy price:0.979|buy volume:49964.14898397203
# buy 160515.OF|buy date:2014-02-10 00:00:00|buy price:0.9952|buy volume:100.0
# buy adjust 160621.OF|buy date:2014-02-07 00:00:00|buy price:0.898|volume from 54013.39821848767 to 533.7666414082341
# buy adjust 161911.OF|buy date:2014-02-07 00:00:00|buy price:0.9156|volume from 12300.0 to 41078.86110671553
# buy adjust 163210.OF|buy date:2014-02-07 00:00:00|buy price:0.896|volume from 5502.0 to 48171.074719185235
# sell 160125.OF|sell date:2014-02-07 00:00:00|sell price:1.1891
# sell 160128.OF at 1.0199
# sell 160515.OF at 0.973
# buy adjust 160621.OF|buy date:2014-03-03 00:00:00|buy price:0.936|volume from 54547.16485989591 to 25832.11964151197
# buy adjust 161911.OF|buy date:2014-03-03 00:00:00|buy price:0.9532|volume from 53378.86110671553 to 26019.36821559907
# buy adjust 163210.OF|buy date:2014-03-03 00:00:00|buy price:0.939|volume from 53673.074719185235 to 26915.53231132283
# buy 164702.OF|buy date:2014-03-04 00:00:00|buy price:0.9842|buy volume:76057.41815947036
# sell 160621.OF at 0.921
# sell 161911.OF at 0.9399
# sell 163210.OF at 0.932
# buy 160128.OF|buy date:2014-04-02 00:00:00|buy price:1.0242|buy volume:57777.517225937576
# buy 161019.OF|buy date:2014-04-02 00:00:00|buy price:1.075|buy volume:54992.42029422792
# buy 161713.OF|buy date:2014-04-02 00:00:00|buy price:1.1884|buy volume:49695.41322632898
# sell adjust 164702.OF|buy date:2014-04-01 00:00:00|buy price:0.9789|volume from 76057.41815947036 to 60270.982603055854
# buy 166902.OF|buy date:2014-04-02 00:00:00|buy price:0.9845|buy volume:10600.0
# sell 160128.OF at 1.0543
# sell 161019.OF at 1.1134
# sell 161713.OF at 1.21
# buy 160515.OF|buy date:2014-05-08 00:00:00|buy price:1.0114|buy volume:87100.0
# buy adjust 164702.OF|buy date:2014-05-05 00:00:00|buy price:1.0009|volume from 60270.982603055854 to 34200.0
# buy adjust 166902.OF|buy date:2014-05-05 00:00:00|buy price:0.9991|volume from 10600.0 to 88670.16826114946
# sell 164702.OF at 1.0386
# sell 166902.OF at 1.0432
# sell 160515.OF at 1.0268
# buy 161911.OF|buy date:2014-06-04 00:00:00|buy price:1.0066|buy volume:152449.70672612544
# buy 163210.OF|buy date:2014-06-04 00:00:00|buy price:0.992|buy volume:81117.0
# scaled buy 160621.OF|buy price:1.005|buy volume:72623.69727924612
# sell adjust 161911.OF|buy date:2014-07-01 00:00:00|buy price:1.0076|volume from 152449.70672612544 to 75888.0943295843
# sell adjust 163210.OF|buy date:2014-07-01 00:00:00|buy price:0.996|volume from 81117.0 to 76675.59663021052
# buy 166902.OF|buy date:2014-07-02 00:00:00|buy price:1.0421|buy volume:73278.3727153626
# sell 166902.OF at 1.0582
# buy adjust 160621.OF|buy date:2014-08-01 00:00:00|buy price:1.008|volume from 72623.69727924612 to 3329.8131877920823
# buy adjust 161911.OF|buy date:2014-08-01 00:00:00|buy price:1.0076|volume from 75888.0943295843 to 14.349754662776832
# buy 163001.OF|buy date:2014-08-04 00:00:00|buy price:0.774|buy volume:38400.0
# sell adjust 163210.OF|buy date:2014-08-01 00:00:00|buy price:0.996|volume from 76675.59663021052 to 76673.10391348922
# sell 161911.OF at 1.0438
# sell 163001.OF at 0.754
# sell adjust 160621.OF|buy date:2014-09-01 00:00:00|buy price:1.0351|volume from 75953.5104670382 to 75094.58032475923
# buy 163110.OF|buy date:2014-09-02 00:00:00|buy price:1.183|buy volume:5202.0
# sell adjust 163210.OF|buy date:2014-09-01 00:00:00|buy price:1.029|volume from 76673.10391348922 to 75531.23429392515
# loss 163110.OF|sell date:2014-09-11 00:00:00|sell price:1.12
# sell 163210.OF at 1.045
# sell 160621.OF at 1.0615
# buy 163821.OF|buy date:2014-10-09 00:00:00|buy price:1.103|buy volume:10800.0
# sell 163821.OF at 1.096
# buy 161117.OF|buy date:2014-12-05 00:00:00|buy price:1.1952|buy volume:16118.0
# loss 161117.OF|sell date:2014-12-02 00:00:00|sell price:1.1234
# buy 160621.OF|buy date:2015-01-06 00:00:00|buy price:1.1519|buy volume:135589.16059425304
# buy 161911.OF|buy date:2015-01-06 00:00:00|buy price:1.0708|buy volume:145495.5489397813
# sell 160621.OF at 1.2005
# sell 161911.OF at 1.1157
# scaled buy 161222.OF|buy price:0.991|buy volume:325183.4804529403
# loss 161222.OF|sell date:2015-07-03 00:00:00|sell price:0.876
# scaled buy 501001.OF|buy price:0.91|buy volume:309919.00413579546
# sell 501001.OF at 0.984
# scaled buy 161225.OF|buy price:0.762|buy volume:396228.1748335419
# profit 161225.OF|sell date:2015-11-11 00:00:00|sell price:0.886
# buy 169101.OF|buy date:2016-02-02 00:00:00|buy price:1.4516|buy volume:119718.25636491198
# buy 501001.OF|buy date:2016-02-02 00:00:00|buy price:0.869|buy volume:199482.99754582037
# sell 169101.OF at 1.4594
# buy 169102.OF|buy date:2016-03-02 00:00:00|buy price:1.2143|buy volume:139484.99851490895
# sell adjust 501001.OF|buy date:2016-03-01 00:00:00|buy price:0.847|volume from 199482.99754582037 to 199474.9690519017
# Not Enough Money in Account:4060.9460431462976
# sell adjust 501001.OF|buy date:2016-04-01 00:00:00|buy price:0.956|volume from 199474.9690519017 to 192040.58727788043
# sell 501001.OF at 0.961
# buy 169101.OF|buy date:2016-05-04 00:00:00|buy price:1.5878|buy volume:116251.52112903242
# buy adjust 169102.OF|buy date:2016-05-03 00:00:00|buy price:1.2835|volume from 139484.99851490895 to 2000.0
# buy adjust 169101.OF|buy date:2016-06-01 00:00:00|buy price:1.5832|volume from 116251.52112903242 to 645.7689486016898
# ...
# buy 501307.OF|buy date:2019-06-06 00:00:00|buy price:0.993|buy volume:1100.0
# buy 502010.OF|buy date:2019-06-04 00:00:00|buy price:0.6664|buy volume:53613.374054801694
# loss 160216.OF|sell date:2019-06-12 00:00:00|sell price:0.438
# sell 163302.OF at 2.6224
# sell 501302.OF at 1.1
# sell 501307.OF at 0.964
# sell 502010.OF at 0.6999
# buy 161907.OF|buy date:2019-07-02 00:00:00|buy price:1.71|buy volume:34733.22207658371
# buy 165311.OF|buy date:2019-07-03 00:00:00|buy price:1.5251|buy volume:1000.0
# buy 501059.OF|buy date:2019-07-02 00:00:00|buy price:1.218|buy volume:4800.0
# loss 501059.OF|sell date:2019-07-04 00:00:00|sell price:1.149
# sell 161907.OF at 1.671
# sell 165311.OF at 1.5309
# buy 163005.OF|buy date:2019-08-06 00:00:00|buy price:1.3094|buy volume:4000.0
# loss 163005.OF|sell date:2019-08-02 00:00:00|sell price:1.1903
# buy 161124.OF|buy date:2019-09-04 00:00:00|buy price:1.064|buy volume:90.0
# sell 161124.OF at 1.103
# buy 160322.OF|buy date:2019-10-10 00:00:00|buy price:1.1335|buy volume:10068.0
# sell 160322.OF|sell date:2019-10-08 00:00:00|sell price:1.1335
# buy 162414.OF|buy date:2019-11-04 00:00:00|buy price:1.399|buy volume:1800.0
# buy 502023.OF|buy date:2019-11-04 00:00:00|buy price:0.8611|buy volume:2000.0
# loss 162414.OF|sell date:2019-11-05 00:00:00|sell price:1.269
# loss 502023.OF|sell date:2019-11-15 00:00:00|sell price:0.8165
# buy 160512.OF|buy date:2019-12-03 00:00:00|buy price:13.5605|buy volume:3223.642850768601
# buy 166009.OF|buy date:2019-12-03 00:00:00|buy price:3.2539|buy volume:1200.0
# buy 168104.OF|buy date:2019-12-03 00:00:00|buy price:1.3091|buy volume:1700.0
# buy 501000.OF|buy date:2019-12-03 00:00:00|buy price:1.144|buy volume:3700.0
# loss 501000.OF|sell date:2019-12-03 00:00:00|sell price:1.048
# sell 160512.OF at 14.2049
# sell 166009.OF at 3.5341
# sell 168104.OF at 1.3132
# buy 161130.OF|buy date:2020-01-03 00:00:00|buy price:1.737|buy volume:16922.234626707093
# buy 164902.OF|buy date:2020-01-06 00:00:00|buy price:1.7059|buy volume:11300.0
# buy 167002.OF|buy date:2020-01-03 00:00:00|buy price:1.266|buy volume:23186.069909563044
# buy 168002.OF|buy date:2020-01-03 00:00:00|buy price:1.3687|buy volume:800.0
# buy 501311.OF|buy date:2020-01-03 00:00:00|buy price:1.086|buy volume:27005.816733655018
# buy 502053.OF|buy date:2020-01-03 00:00:00|buy price:1.3326|buy volume:10032.0
# sell 501311.OF|sell date:2020-01-02 00:00:00|sell price:1.086
# loss 161130.OF|sell date:2020-01-06 00:00:00|sell price:1.585
# loss 167002.OF|sell date:2020-01-06 00:00:00|sell price:1.178
# loss 164902.OF|sell date:2020-01-08 00:00:00|sell price:1.5972
# buy 161130.OF|buy date:2020-02-04 00:00:00|buy price:1.599|buy volume:17649.41296057405
# buy 164902.OF|buy date:2020-02-04 00:00:00|buy price:1.758|buy volume:4500.0
# buy 167002.OF|buy date:2020-02-04 00:00:00|buy price:1.227|buy volume:500.0
# buy adjust 168002.OF|buy date:2020-02-03 00:00:00|buy price:1.4065|volume from 800.0 to 6100.0
# buy 501311.OF|buy date:2020-02-04 00:00:00|buy price:1.04|buy volume:27099.834557476453
# buy adjust 502053.OF|buy date:2020-02-03 00:00:00|buy price:1.2337|volume from 10032.0 to 13936.387322212024
# sell 501311.OF|sell date:2020-02-03 00:00:00|sell price:1.04
# profit 167002.OF|sell date:2020-02-11 00:00:00|sell price:1.43
# profit 168002.OF|sell date:2020-02-14 00:00:00|sell price:1.6496
# sell 161130.OF|sell date:2020-02-18 00:00:00|sell price:1.65
# sell 502053.OF at 1.1776
# sell 164902.OF at 1.7312
# buy 160622.OF|buy date:2020-03-03 00:00:00|buy price:1.2547|buy volume:14800.0
# buy 160723.OF|buy date:2020-03-03 00:00:00|buy price:1.056|buy volume:39920.24988763258
# buy 161116.OF|buy date:2020-03-03 00:00:00|buy price:0.863|buy volume:48787.19735147557
# buy 501032.OF|buy date:2020-03-03 00:00:00|buy price:0.8218|buy volume:6400.0
# loss 160723.OF|sell date:2020-03-05 00:00:00|sell price:0.989
# loss 501032.OF|sell date:2020-03-05 00:00:00|sell price:0.7723
# loss 160622.OF|sell date:2020-03-06 00:00:00|sell price:1.1864
# loss 161116.OF|sell date:2020-03-13 00:00:00|sell price:0.789
# buy 160613.OF|buy date:2020-04-02 00:00:00|buy price:3.4644|buy volume:4100.0
# buy 162105.OF|buy date:2020-04-10 00:00:00|buy price:1.234|buy volume:1100.0
# buy 162719.OF|buy date:2020-04-02 00:00:00|buy price:0.632|buy volume:50641.07407622711
# buy 165508.OF|buy date:2020-04-07 00:00:00|buy price:1.653|buy volume:3056.0
# buy 168002.OF|buy date:2020-04-02 00:00:00|buy price:1.4243|buy volume:100.0
# profit 162719.OF|sell date:2020-04-09 00:00:00|sell price:0.749
# loss 160613.OF|sell date:2020-04-10 00:00:00|sell price:3.2787
# loss 168002.OF|sell date:2020-04-13 00:00:00|sell price:1.3279
# sell 162105.OF at 1.224
# sell 165508.OF at 1.695
# buy 160140.OF|buy date:2020-06-02 00:00:00|buy price:1.0048|buy volume:72350.0
# buy 501059.OF|buy date:2020-06-02 00:00:00|buy price:1.263|buy volume:2731.0
# loss 160140.OF|sell date:2020-06-29 00:00:00|sell price:0.9397
# sell 501059.OF at 1.265
# buy 160723.OF|buy date:2020-07-02 00:00:00|buy price:0.674|buy volume:236471.4255085174
# sell 160723.OF|sell date:2020-07-02 00:00:00|sell price:0.672
# buy 165510.OF|buy date:2020-09-02 00:00:00|buy price:0.826|buy volume:70223.0
# buy 501018.OF|buy date:2020-09-02 00:00:00|buy price:0.605|buy volume:129784.32873813994
# sell 501018.OF|sell date:2020-09-01 00:00:00|sell price:0.605
# sell 165510.OF|sell date:2020-09-08 00:00:00|sell price:0.817
# buy 162307.OF|buy date:2020-10-12 00:00:00|buy price:1.9664|buy volume:25934.0
# buy 502053.OF|buy date:2020-10-12 00:00:00|buy price:1.5639|buy volume:49584.28865015332
# loss 502053.OF|sell date:2020-10-19 00:00:00|sell price:1.473
# sell 162307.OF at 1.9292
# buy 160723.OF|buy date:2020-11-03 00:00:00|buy price:0.563|buy volume:264026.5070682858
# sell 160723.OF|sell date:2020-11-27 00:00:00|sell price:0.631
# buy 161129.OF|buy date:2020-12-02 00:00:00|buy price:0.583|buy volume:94307.03676033094
# buy 165508.OF|buy date:2020-12-03 00:00:00|buy price:2.637|buy volume:900.0
# loss 165508.OF|sell date:2020-12-07 00:00:00|sell price:2.436
# sell 161129.OF|sell date:2020-12-29 00:00:00|sell price:0.562
# buy 161908.OF|buy date:2021-01-05 00:00:00|buy price:1.6402|buy volume:11200.0
# buy 162307.OF|buy date:2021-01-05 00:00:00|buy price:2.2002|buy volume:36846.896115022566
# loss 161908.OF|sell date:2021-01-05 00:00:00|sell price:1.5318
# sell 162307.OF at 2.2347
# buy 168401.OF|buy date:2021-02-02 00:00:00|buy price:2.2|buy volume:12156.0
# buy 501203.OF|buy date:2021-02-02 00:00:00|buy price:1.232|buy volume:65408.49595001203
# loss 168401.OF|sell date:2021-02-04 00:00:00|sell price:2.075
# sell 501203.OF at 1.188
# buy 164105.OF|buy date:2021-03-02 00:00:00|buy price:2.2864|buy volume:13562.0
# sell 164105.OF at 2.2625
# buy 160415.OF|buy date:2021-04-02 00:00:00|buy price:1.5716|buy volume:43452.0
# buy 501040.OF|buy date:2021-04-02 00:00:00|buy price:1.315|buy volume:58900.66513180791
# loss 160415.OF|sell date:2021-04-07 00:00:00|sell price:1.4537
# loss 501040.OF|sell date:2021-04-13 00:00:00|sell price:1.231
# buy 163907.OF|buy date:2021-06-02 00:00:00|buy price:1.1524|buy volume:51270.0
# buy 166401.OF|buy date:2021-06-02 00:00:00|buy price:1.3604|buy volume:41427.0
# loss 166401.OF|sell date:2021-06-03 00:00:00|sell price:1.2253
# sell 163907.OF at 1.1305
# buy 501012.OF|buy date:2021-07-02 00:00:00|buy price:1.485|buy volume:91600.31422579917
# loss 501012.OF|sell date:2021-07-05 00:00:00|sell price:1.326
# buy 162207.OF|buy date:2021-08-03 00:00:00|buy price:4.7995|buy volume:25055.409810017038
# loss 162207.OF|sell date:2021-08-17 00:00:00|sell price:4.535
# buy 160925.OF|buy date:2021-10-11 00:00:00|buy price:1.269|buy volume:12960.0
# buy 161038.OF|buy date:2021-10-11 00:00:00|buy price:1.628|buy volume:22715.0
# buy 161225.OF|buy date:2021-10-11 00:00:00|buy price:2.5895|buy volume:13218.0
# sell 160925.OF|sell date:2021-10-08 00:00:00|sell price:1.269
# loss 161038.OF|sell date:2021-10-19 00:00:00|sell price:1.53
# sell 161225.OF at 2.5073
# buy 160216.OF|buy date:2021-12-02 00:00:00|buy price:0.315|buy volume:171974.38633654758
# buy 501032.OF|buy date:2021-12-02 00:00:00|buy price:1.6158|buy volume:33442.98529955282
# loss 501032.OF|sell date:2021-12-09 00:00:00|sell price:1.5217
# sell 160216.OF|sell date:2021-12-27 00:00:00|sell price:0.314
# buy 163115.OF|buy date:2022-02-08 00:00:00|buy price:1.248|buy volume:40255.0
# buy 501086.OF|buy date:2022-02-08 00:00:00|buy price:1.469|buy volume:35306.7663483283
# loss 163115.OF|sell date:2022-02-11 00:00:00|sell price:1.16
# sell 501086.OF at 1.468
# buy 160642.OF|buy date:2022-03-02 00:00:00|buy price:2.1086|buy volume:800.0
# buy 161117.OF|buy date:2022-03-02 00:00:00|buy price:1.9041|buy volume:17403.62415969658
# buy 162719.OF|buy date:2022-03-02 00:00:00|buy price:1.699|buy volume:19472.2102056052
# loss 162719.OF|sell date:2022-03-04 00:00:00|sell price:1.573
# loss 161117.OF|sell date:2022-03-07 00:00:00|sell price:1.8006
# loss 160642.OF|sell date:2022-03-08 00:00:00|sell price:1.9972
# processing group 13|8 10
# buy 161219.OF|buy date:2014-03-04 00:00:00|buy price:1.4337|buy volume:2102.0
# loss 161219.OF|sell date:2014-03-10 00:00:00|sell price:1.3446
# buy 165512.OF|buy date:2014-04-02 00:00:00|buy price:1.201|buy volume:711.0
# sell 165512.OF at 1.208
# buy 163415.OF|buy date:2014-09-03 00:00:00|buy price:1.29|buy volume:800.0
# loss 163415.OF|sell date:2014-09-11 00:00:00|sell price:1.19
# buy 161820.OF|buy date:2014-10-09 00:00:00|buy price:1.2222|buy volume:100906.0
# loss 161820.OF|sell date:2014-10-09 00:00:00|sell price:1.1418
# buy 165513.OF|buy date:2014-12-02 00:00:00|buy price:0.827|buy volume:349383.0166603499
# profit 165513.OF|sell date:2014-12-08 00:00:00|sell price:0.967
# buy 165311.OF|buy date:2015-05-05 00:00:00|buy price:1.4764|buy volume:166870.0
# sell 165311.OF at 1.5367
# buy 165509.OF|buy date:2015-08-04 00:00:00|buy price:1.5888|buy volume:9900.0
# sell 165509.OF at 1.5385
# buy 160415.OF|buy date:2015-09-02 00:00:00|buy price:1.282|buy volume:13600.0
# buy 160616.OF|buy date:2015-09-02 00:00:00|buy price:1.326|buy volume:58010.0
# loss 160415.OF|sell date:2015-09-11 00:00:00|sell price:1.216
# loss 160616.OF|sell date:2015-09-14 00:00:00|sell price:1.192
# buy 161117.OF|buy date:2015-11-03 00:00:00|buy price:1.4992|buy volume:15300.0
# loss 161117.OF|sell date:2015-11-10 00:00:00|sell price:1.4235
# buy 161225.OF|buy date:2015-12-02 00:00:00|buy price:0.945|buy volume:349687.1972834301
# sell 161225.OF at 1.049
# buy 161119.OF|buy date:2016-02-04 00:00:00|buy price:1.21|buy volume:900.0
# sell 161119.OF at 1.205
# buy 160515.OF|buy date:2016-04-05 00:00:00|buy price:1.4552|buy volume:68800.0
# loss 160515.OF|sell date:2016-04-26 00:00:00|sell price:1.3484
# buy 160515.OF|buy date:2016-06-02 00:00:00|buy price:1.3884|buy volume:13000.0
# sell 160515.OF at 1.3714
# buy 160515.OF|buy date:2016-09-02 00:00:00|buy price:1.4025|buy volume:4200.0
# sell 160515.OF|sell date:2016-09-26 00:00:00|sell price:1.4386
# buy 161015.OF|buy date:2016-12-02 00:00:00|buy price:1.2321|buy volume:58800.0
# sell 161015.OF at 1.2081
# buy 164906.OF|buy date:2017-04-06 00:00:00|buy price:1.149|buy volume:306754.3620457907
# loss 164906.OF|sell date:2017-04-17 00:00:00|sell price:1.085
# buy 160415.OF|buy date:2017-06-02 00:00:00|buy price:1.209|buy volume:206357.0
# sell 160415.OF at 1.26
# buy 165309.OF|buy date:2017-11-02 00:00:00|buy price:1.305|buy volume:110200.0
# loss 165309.OF|sell date:2017-11-03 00:00:00|sell price:1.217
# scaled buy 169101.OF|buy price:3.0789|buy volume:106018.62500178462
# sell adjust 169101.OF|buy date:2018-01-02 00:00:00|buy price:3.3387|volume from 106018.62500178462 to 20571.896073042382
# buy 169103.OF|buy date:2018-01-03 00:00:00|buy price:1.9148|buy volume:35721.4997564338
# buy 169104.OF|buy date:2018-01-03 00:00:00|buy price:1.82|buy volume:37544.76291321081
# buy 169105.OF|buy date:2018-01-03 00:00:00|buy price:1.911|buy volume:35721.33803825033
# sell 169101.OF at 3.1146
# sell 169105.OF at 1.8689
# buy adjust 169103.OF|buy date:2018-02-01 00:00:00|buy price:1.921|volume from 35721.4997564338 to 54451.003478205515
# Not Enough Money in Account:102891.43573002539
# loss 169104.OF|sell date:2018-02-06 00:00:00|sell price:1.7011
# loss 169103.OF|sell date:2018-02-09 00:00:00|sell price:1.7121
# buy 169104.OF|buy date:2018-03-02 00:00:00|buy price:1.7337|buy volume:31400.0
# loss 169104.OF|sell date:2018-03-23 00:00:00|sell price:1.63
# buy 161129.OF|buy date:2018-10-09 00:00:00|buy price:1.804|buy volume:87221.22070214778
# loss 161129.OF|sell date:2018-10-12 00:00:00|sell price:1.544
# buy 163005.OF|buy date:2019-05-07 00:00:00|buy price:1.0924|buy volume:900.0
# buy 501067.OF|buy date:2019-05-07 00:00:00|buy price:1.181|buy volume:123061.71037180885
# sell 501067.OF|sell date:2019-05-06 00:00:00|sell price:1.181
# sell 163005.OF at 1.0949
# buy 164606.OF|buy date:2019-07-03 00:00:00|buy price:1.359|buy volume:12792.0
# sell 164606.OF at 1.4069
# buy 502023.OF|buy date:2019-09-04 00:00:00|buy price:0.8462|buy volume:65026.0
# sell 502023.OF|sell date:2019-09-04 00:00:00|sell price:0.8359
# buy 162411.OF|buy date:2020-03-03 00:00:00|buy price:0.329|buy volume:219183.90094452698
# buy 162719.OF|buy date:2020-03-03 00:00:00|buy price:0.799|buy volume:90139.94053330306
# buy 164703.OF|buy date:2020-03-03 00:00:00|buy price:1.1572|buy volume:62160.588590861844
# buy 168401.OF|buy date:2020-03-03 00:00:00|buy price:1.477|buy volume:9516.0
# loss 162719.OF|sell date:2020-03-06 00:00:00|sell price:0.705
# loss 162411.OF|sell date:2020-03-09 00:00:00|sell price:0.287
# loss 168401.OF|sell date:2020-03-09 00:00:00|sell price:1.402
# sell 164703.OF at 1.1298
# buy 160140.OF|buy date:2020-04-02 00:00:00|buy price:0.956|buy volume:32400.0
# buy 166107.OF|buy date:2020-04-02 00:00:00|buy price:1.12|buy volume:16300.0
# buy 502040.OF|buy date:2020-04-02 00:00:00|buy price:1.3963|buy volume:15800.0
# loss 166107.OF|sell date:2020-04-02 00:00:00|sell price:1.063
# sell 160140.OF|sell date:2020-04-13 00:00:00|sell price:0.9804
# sell 502040.OF at 1.4335
# buy 502053.OF|buy date:2020-05-07 00:00:00|buy price:1.1749|buy volume:10798.0
# loss 502053.OF|sell date:2020-05-27 00:00:00|sell price:1.1121
# buy 165510.OF|buy date:2020-06-02 00:00:00|buy price:0.696|buy volume:88578.0
# buy 502053.OF|buy date:2020-06-02 00:00:00|buy price:1.1816|buy volume:39400.0
# sell 165510.OF at 0.712
# sell 502053.OF at 1.1763
# scaled buy 502053.OF|buy price:1.616|buy volume:164181.28107344836
# loss 502053.OF|sell date:2020-08-12 00:00:00|sell price:1.5345
# scaled buy 161129.OF|buy price:0.613|buy volume:406899.426080317
# sell 161129.OF|sell date:2020-09-01 00:00:00|sell price:0.613
# scaled buy 161129.OF|buy price:0.562|buy volume:439408.29915599606
# loss 161129.OF|sell date:2020-10-26 00:00:00|sell price:0.533
# buy 161129.OF|buy date:2020-11-03 00:00:00|buy price:0.507|buy volume:228673.79113593334
# buy 501018.OF|buy date:2020-11-03 00:00:00|buy price:0.507|buy volume:228104.9508594758
# sell 161129.OF|sell date:2020-11-04 00:00:00|sell price:0.518
# sell 501018.OF|sell date:2020-11-04 00:00:00|sell price:0.514
# buy 165317.OF|buy date:2021-03-02 00:00:00|buy price:2.281|buy volume:19543.0
# buy 166107.OF|buy date:2021-03-02 00:00:00|buy price:1.443|buy volume:8250.0
# buy 169201.OF|buy date:2021-03-02 00:00:00|buy price:1.933|buy volume:40241.61072078784
# loss 169201.OF|sell date:2021-03-04 00:00:00|sell price:1.802
# loss 165317.OF|sell date:2021-03-08 00:00:00|sell price:2.087
# loss 166107.OF|sell date:2021-03-08 00:00:00|sell price:1.333
# buy 166902.OF|buy date:2021-06-02 00:00:00|buy price:1.8343|buy volume:600.0
# loss 166902.OF|sell date:2021-06-09 00:00:00|sell price:1.7386
# buy 161233.OF|buy date:2021-07-02 00:00:00|buy price:1.468|buy volume:6596.0
# sell 161233.OF at 1.501
# buy 168301.OF|buy date:2021-09-02 00:00:00|buy price:1.3996|buy volume:6700.0
# loss 168301.OF|sell date:2021-09-16 00:00:00|sell price:1.3065
# buy 160105.OF|buy date:2021-11-02 00:00:00|buy price:7.3839|buy volume:15300.0
# sell 160105.OF at 7.5498
# buy 160722.OF|buy date:2022-01-05 00:00:00|buy price:1.7374|buy volume:7579.0
# loss 160722.OF|sell date:2022-01-10 00:00:00|sell price:1.6442
# scaled buy 161219.OF|buy price:5.8753|buy volume:37841.9553181387
# loss 161219.OF|sell date:2022-02-23 00:00:00|sell price:5.5577

# %% [markdown]
# #### 4.统计净值变动

# %%
fig = plt.figure(figsize = (18,6),dpi = 150)
ax1 = fig.add_subplot(111)
ax1.plot(backtest_result.iloc[:,:7], "-",linewidth = 1.15,label = backtest_result.columns[:7])#非预测对比序列
plt.xticks(fontproperties='Times New Roman', size = 11.5)
plt.yticks(fontproperties='Times New Roman', size = 11.5)
ax1.set_ylabel("Net Value (Adjusted)",fontsize = 12,weight = 'bold')
ax1.set_xlabel("Years",fontsize = 12,weight = 'bold')

plt.legend(loc = 'upper left',fontsize = 11,shadow = "gray",fancybox = False)
# plt.savefig('./Plots/GroupAccountBalance/AccountBalance(Pressure)',bbox_inches = 'tight')

# %%
risk_stats:pd.DataFrame = pd.DataFrame(columns = [f"Group {i}" for i in range(14)],index = ["Sharpe","AnnualReturn","MaxDrawdown","ub(%)","lb(%)"])

# %%
rf = 0.00011741094678452413
for ix,group in enumerate(risk_stats.columns):
    # Sharpe
    sharpe = empyrical.sharpe_ratio(backtest_result.loc[:,group].pct_change().dropna().values, risk_free = rf, period = 'daily', annualization = 365)
    # annual return
    annual_return = empyrical.annual_return(backtest_result.loc[:,group].pct_change().dropna().values,period = 'daily',annualization = 365)
    # max drawdown
    max_drawdown = ((backtest_result.loc[:,group].cummax() - backtest_result.loc[:,group])/(backtest_result.loc[:,group].cummax())).max()
    # discount upper bound
    ub = discount_ubs[ix]
    # discount lower bound
    lb = discount_lbs[ix]
    risk_stats.loc[["Sharpe","AnnualReturn","MaxDrawdown","ub(%)","lb(%)"],group] = sharpe,annual_return,max_drawdown,ub,lb

# %%
risk_stats.to_excel('./Output/AccountBalance(GroupPressure).xlsx')
